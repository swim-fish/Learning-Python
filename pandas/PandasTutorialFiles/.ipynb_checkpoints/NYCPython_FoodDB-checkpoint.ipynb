# %%
from pandas import *
import pandas as pd
import json
import matplotlib.pyplot as plt
# Enable inline plott
# %matplotlib inline

db_path = 'foods-2011-10-03.json'
db = json.load(open(db_path))
#set_printoptions(max_columns=10, notebook_repr_html=False)
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))

# %%
len(db)
# Out:
# 6636

# %%
df = DataFrame(db[0]['nutrients'])

# %%
df
# Out:
#                             description        group    units     value
# 0                               Protein  Composition        g    25.180
# 1                     Total lipid (fat)  Composition        g    29.200
# 2           Carbohydrate, by difference  Composition        g     3.060
# 3                                   Ash        Other        g     3.280
# 4                                Energy       Energy     kcal   376.000
# 5                                 Water  Composition        g    39.280
# 6                                Energy       Energy       kJ  1573.000
# 7                  Fiber, total dietary  Composition        g     0.000
# 8                           Calcium, Ca     Elements       mg   673.000
# 9                              Iron, Fe     Elements       mg     0.640
# 10                        Magnesium, Mg     Elements       mg    22.000
# 11                        Phosphorus, P     Elements       mg   490.000
# ...

# %%
id_keys = ['description', 'group', 'id', 'manufacturer']
info = DataFrame(db, columns=id_keys)
print(info[:50].to_string())
# Out:
#                                           description                   group    id manufacturer
# 0                                     Cheese, caraway  Dairy and Egg Products  1008
# 1                                     Cheese, cheddar  Dairy and Egg Products  1009
# 2                                        Cheese, edam  Dairy and Egg Products  1018
# 3                                        Cheese, feta  Dairy and Egg Products  1019
# 4                  Cheese, mozzarella, part skim milk  Dairy and Egg Products  1028
# 5    Cheese, mozzarella, part skim milk, low moisture  Dairy and Egg Products  1029
# 6                                      Cheese, romano  Dairy and Egg Products  1038
# 7                                   Cheese, roquefort  Dairy and Egg Products  1039
# 8   Cheese spread, pasteurized process, american, ...  Dairy and Egg Products  1048
# 9                         Cream, fluid, half and half  Dairy and Egg Products  1049
# ...

# %%
info['group']
# Out:
# 0     Dairy and Egg Products
# 1     Dairy and Egg Products
# 2     Dairy and Egg Products
# 3     Dairy and Egg Products
# 4     Dairy and Egg Products
# 5     Dairy and Egg Products
# 6     Dairy and Egg Products
# 7     Dairy and Egg Products
# 8     Dairy and Egg Products
# 9     Dairy and Egg Products
# 10    Dairy and Egg Products
# 11    Dairy and Egg Products
# 12    Dairy and Egg Products
# 13    Dairy and Egg Products
# 14    Dairy and Egg Products
# ...
# 6621           Soups, Sauces, and Gravies
# 6622           Soups, Sauces, and Gravies
# 6623           Soups, Sauces, and Gravies
# 6624           Soups, Sauces, and Gravies
# 6625           Soups, Sauces, and Gravies
# 6626    Vegetables and Vegetable Products
# 6627    Vegetables and Vegetable Products
# 6628    Vegetables and Vegetable Products
# 6629    Vegetables and Vegetable Products
# 6630    Vegetables and Vegetable Products
# 6631          Sausages and Luncheon Meats
# 6632          Sausages and Luncheon Meats
# ...

# %%
plt.figure(figsize=(15, 6))
info.group.value_counts().plot(kind='bar', rot=90)

# %%
info.group
# Out:
# 0     Dairy and Egg Products
# 1     Dairy and Egg Products
# 2     Dairy and Egg Products
# 3     Dairy and Egg Products
# 4     Dairy and Egg Products
# 5     Dairy and Egg Products
# 6     Dairy and Egg Products
# 7     Dairy and Egg Products
# 8     Dairy and Egg Products
# 9     Dairy and Egg Products
# 10    Dairy and Egg Products
# 11    Dairy and Egg Products
# 12    Dairy and Egg Products
# 13    Dairy and Egg Products
# 14    Dairy and Egg Products
# ...
# 6621           Soups, Sauces, and Gravies
# 6622           Soups, Sauces, and Gravies
# 6623           Soups, Sauces, and Gravies
# 6624           Soups, Sauces, and Gravies
# 6625           Soups, Sauces, and Gravies
# 6626    Vegetables and Vegetable Products
# 6627    Vegetables and Vegetable Products
# 6628    Vegetables and Vegetable Products
# 6629    Vegetables and Vegetable Products
# 6630    Vegetables and Vegetable Products
# 6631          Sausages and Luncheon Meats
# 6632          Sausages and Luncheon Meats
# ...

# %%
info.dtypes
# Out:
# description     object
# group           object
# id               int64
# manufacturer    object
# dtype: object

# %%
info
# Out:
#                                             description  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# ...

# %%
col_mapping = {'description' : 'food',
               'group'       : 'fgroup'}
info = info.rename(columns=col_mapping, copy=False)
info
# Out:
#                                                    food  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# ...

# %%
DataFrame(db[0]['nutrients'])
# Out:
#                             description        group    units     value
# 0                               Protein  Composition        g    25.180
# 1                     Total lipid (fat)  Composition        g    29.200
# 2           Carbohydrate, by difference  Composition        g     3.060
# 3                                   Ash        Other        g     3.280
# 4                                Energy       Energy     kcal   376.000
# 5                                 Water  Composition        g    39.280
# 6                                Energy       Energy       kJ  1573.000
# 7                  Fiber, total dietary  Composition        g     0.000
# 8                           Calcium, Ca     Elements       mg   673.000
# 9                              Iron, Fe     Elements       mg     0.640
# 10                        Magnesium, Mg     Elements       mg    22.000
# 11                        Phosphorus, P     Elements       mg   490.000
# ...

# %%
all_nutrients = []
for rec in db:
    nutrients = DataFrame(rec['nutrients'])
    nutrients['id'] = rec['id']
    all_nutrients.append(nutrients)
all_nutrients = concat(all_nutrients, ignore_index=True)

# %%
all_nutrients[:50]
# Out:
#                            description        group    units     value    id
# 0                              Protein  Composition        g    25.180  1008
# 1                    Total lipid (fat)  Composition        g    29.200  1008
# 2          Carbohydrate, by difference  Composition        g     3.060  1008
# 3                                  Ash        Other        g     3.280  1008
# 4                               Energy       Energy     kcal   376.000  1008
# 5                                Water  Composition        g    39.280  1008
# 6                               Energy       Energy       kJ  1573.000  1008
# 7                 Fiber, total dietary  Composition        g     0.000  1008
# 8                          Calcium, Ca     Elements       mg   673.000  1008
# 9                             Iron, Fe     Elements       mg     0.640  1008
# 10                       Magnesium, Mg     Elements       mg    22.000  1008
# ...

# %%
all_nutrients = all_nutrients.drop_duplicates()

# %%
all_nutrients
# Out:
#                                description        group    units     value  \
# 0                                  Protein  Composition        g    25.180
# 1                        Total lipid (fat)  Composition        g    29.200
# 2              Carbohydrate, by difference  Composition        g     3.060
# 3                                      Ash        Other        g     3.280
# 4                                   Energy       Energy     kcal   376.000
# 5                                    Water  Composition        g    39.280
# 6                                   Energy       Energy       kJ  1573.000
# 7                     Fiber, total dietary  Composition        g     0.000
# 8                              Calcium, Ca     Elements       mg   673.000
# 9                                 Iron, Fe     Elements       mg     0.640
# 10                           Magnesium, Mg     Elements       mg    22.000
# ...

# %%
col_mapping = {'description' : 'nutrient',
               'group' : 'nutgroup'}
all_nutrients = all_nutrients.rename(columns=col_mapping)
all_nutrients
# Out:
#                                   nutrient     nutgroup    units     value  \
# 0                                  Protein  Composition        g    25.180
# 1                        Total lipid (fat)  Composition        g    29.200
# 2              Carbohydrate, by difference  Composition        g     3.060
# 3                                      Ash        Other        g     3.280
# 4                                   Energy       Energy     kcal   376.000
# 5                                    Water  Composition        g    39.280
# 6                                   Energy       Energy       kJ  1573.000
# 7                     Fiber, total dietary  Composition        g     0.000
# 8                              Calcium, Ca     Elements       mg   673.000
# 9                                 Iron, Fe     Elements       mg     0.640
# 10                           Magnesium, Mg     Elements       mg    22.000
# ...

# %%
all_nutrients[:100]
# Out:
#                            nutrient     nutgroup    units     value    id
# 0                           Protein  Composition        g    25.180  1008
# 1                 Total lipid (fat)  Composition        g    29.200  1008
# 2       Carbohydrate, by difference  Composition        g     3.060  1008
# 3                               Ash        Other        g     3.280  1008
# 4                            Energy       Energy     kcal   376.000  1008
# 5                             Water  Composition        g    39.280  1008
# 6                            Energy       Energy       kJ  1573.000  1008
# 7              Fiber, total dietary  Composition        g     0.000  1008
# 8                       Calcium, Ca     Elements       mg   673.000  1008
# 9                          Iron, Fe     Elements       mg     0.640  1008
# 10                    Magnesium, Mg     Elements       mg    22.000  1008
# 11                    Phosphorus, P     Elements       mg   490.000  1008
# ...

# %%
info
# Out:
#                                                    food  \
# 0                                       Cheese, caraway
# 1                                       Cheese, cheddar
# 2                                          Cheese, edam
# 3                                          Cheese, feta
# 4                    Cheese, mozzarella, part skim milk
# 5      Cheese, mozzarella, part skim milk, low moisture
# 6                                        Cheese, romano
# 7                                     Cheese, roquefort
# 8     Cheese spread, pasteurized process, american, ...
# 9                           Cream, fluid, half and half
# 10    Sour dressing, non-butterfat, cultured, filled...
# 11    Milk, filled, fluid, with blend of hydrogenate...
# 12    Cream substitute, liquid, with lauric acid oil...
# 13                           Cream substitute, powdered
# 14                  Milk, producer, fluid, 3.7% milkfat
# 15    Milk, reduced fat, fluid, 2% milkfat, with add...
# ...

# %%
nd = merge(all_nutrients, info, on='id', how='outer')
nd
# Out:
#                                   nutrient     nutgroup    units     value  \
# 0                                  Protein  Composition        g    25.180
# 1                        Total lipid (fat)  Composition        g    29.200
# 2              Carbohydrate, by difference  Composition        g     3.060
# 3                                      Ash        Other        g     3.280
# 4                                   Energy       Energy     kcal   376.000
# 5                                    Water  Composition        g    39.280
# 6                                   Energy       Energy       kJ  1573.000
# 7                     Fiber, total dietary  Composition        g     0.000
# 8                              Calcium, Ca     Elements       mg   673.000
# 9                                 Iron, Fe     Elements       mg     0.640
# 10                           Magnesium, Mg     Elements       mg    22.000
# ...

# %%
nd[:10]
# Out:
#                       nutrient     nutgroup units    value    id  \
# 0                      Protein  Composition     g    25.18  1008
# 1            Total lipid (fat)  Composition     g    29.20  1008
# 2  Carbohydrate, by difference  Composition     g     3.06  1008
# 3                          Ash        Other     g     3.28  1008
# 4                       Energy       Energy  kcal   376.00  1008
# 5                        Water  Composition     g    39.28  1008
# 6                       Energy       Energy    kJ  1573.00  1008
# 7         Fiber, total dietary  Composition     g     0.00  1008
# 8                  Calcium, Ca     Elements    mg   673.00  1008
# 9                     Iron, Fe     Elements    mg     0.64  1008
#
#               food                  fgroup manufacturer
# 0  Cheese, caraway  Dairy and Egg Products
# 1  Cheese, caraway  Dairy and Egg Products
# 2  Cheese, caraway  Dairy and Egg Products
# 3  Cheese, caraway  Dairy and Egg Products
# ...

# %%
result = nd.groupby(['nutrient', 'fgroup'])['value'].quantile(0.5)

# %%
result['Zinc, Zn'].order().plot(kind='bar', rot=90)

# %%
from scipy.stats import scoreatpercentile

grouped = nd.groupby(['nutrient', 'fgroup'])['value']

result = grouped.max()

# nd.groupby('nutrient')['value'].describe()

# grouped.apply(lambda x: scoreatpercentile(x.dropna().values, 1)).ix['Protein']

# %%
result.ix[:, 'Sweets']
# Out:
# nutrient
# Adjusted Protein                 12.900
# Alanine                           8.009
# Alcohol, ethyl                    0.000
# Arginine                          6.616
# Ash                              72.500
# Aspartic acid                     5.265
# Beta-sitosterol                  86.000
# Betaine                           6.100
# Caffeine                        839.000
# Calcium, Ca                    3733.000
# Campesterol                      13.000
# Carbohydrate, by difference     100.000
# Carotene, alpha                   9.000
# Carotene, beta                  135.000
# Cholesterol                     258.000
# ...
# Valine                               2.081
# Vitamin A, IU                     1152.000
# Vitamin A, RAE                     319.000
# Vitamin B-12                         4.090
# Vitamin B-12, added                  0.050
# Vitamin B-6                          1.500
# Vitamin C, total ascorbic acid     490.000
# ...

# %%
# kCal and kJ
crit = (nd.nutrient == 'Energy') & (nd.units == 'kJ')
nd = nd[-crit]
nd = nd.sort_index(by=['id', 'nutrient'])
nd
# Out:
#                                   nutrient     nutgroup    units    value  \
# 48                                 Alanine  Amino Acids        g    0.711
# 46                                Arginine  Amino Acids        g    0.952
# 3                                      Ash        Other        g    3.280
# 49                           Aspartic acid  Amino Acids        g    1.618
# 8                              Calcium, Ca     Elements       mg  673.000
# 2              Carbohydrate, by difference  Composition        g    3.060
# 32                             Cholesterol        Other       mg   93.000
# 15                              Copper, Cu     Elements       mg    0.024
# 42                                 Cystine  Amino Acids        g    0.126
# 4                                   Energy       Energy     kcal  376.000
# 34      Fatty acids, total monounsaturated        Other        g    8.275
# 35      Fatty acids, total polyunsaturated        Other        g    0.830
# ...

# %%
ind = nd.set_index(['id', 'nutrient'])
ind
# Out:
#                                              nutgroup    units    value  \
# id    nutrient
# 1008  Alanine                             Amino Acids        g    0.711
#       Arginine                            Amino Acids        g    0.952
#       Ash                                       Other        g    3.280
#       Aspartic acid                       Amino Acids        g    1.618
#       Calcium, Ca                            Elements       mg  673.000
#       Carbohydrate, by difference         Composition        g    3.060
#       Cholesterol                               Other       mg   93.000
#       Copper, Cu                             Elements       mg    0.024
#       Cystine                             Amino Acids        g    0.126
#       Energy                                   Energy     kcal  376.000
#       Fatty acids, total monounsaturated        Other        g    8.275
#       Fatty acids, total polyunsaturated        Other        g    0.830
# ...

# %%
ind.ix[1079]
# Out:
#                                        nutgroup    units    value  \
# nutrient
# Alanine                             Amino Acids        g    0.111
# Alcohol, ethyl                            Other        g    0.000
# Arginine                            Amino Acids        g    0.107
# Ash                                       Other        g    0.710
# Aspartic acid                       Amino Acids        g    0.299
# Beta-sitosterol                           Other       mg    0.000
# Betaine                                Vitamins       mg    0.900
# Caffeine                                  Other       mg    0.000
# Calcium, Ca                            Elements       mg  120.000
# Campesterol                               Other       mg    0.000
# Carbohydrate, by difference         Composition        g    4.800
# Carotene, alpha                        Vitamins      mcg    0.000
# Carotene, beta                         Vitamins      mcg    4.000
# ...

# %%
ndg = nd[nd.units == 'g']
table = pivot_table(ndg, 'value', rows=['nutgroup', 'nutrient'], cols=['fgroup'])
# Out:
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/util/decorators.py:53: FutureWarning: cols is deprecated, use columns instead
#   warnings.warn(msg, FutureWarning)
# /opt/local/Library/Frameworks/Python.framework/Versions/3.4/lib/python3.4/site-packages/pandas/util/decorators.py:53: FutureWarning: rows is deprecated, use index instead
#   warnings.warn(msg, FutureWarning)

# %%
table.columns.name
# Out:
# 'fgroup'

# %%
table[['Breakfast Cereals', 'Fast Foods', 'Sweets', 'Snacks']]
# Out:
# fgroup                                          Breakfast Cereals  Fast Foods  \
# nutgroup    nutrient
# Amino Acids Alanine                                      0.340753    0.580446
#             Arginine                                     0.345178    0.631418
#             Aspartic acid                                0.513767    0.922457
#             Cystine                                      0.128384    0.156164
#             Glutamic acid                                1.702151    2.605777
#             Glycine                                      0.292932    0.634790
#             Histidine                                    0.162411    0.322116
#             Hydroxyproline                               0.000000    0.388067
#             Isoleucine                                   0.251233    0.480755
#             Leucine                                      0.574699    0.895275
#             Lysine                                       0.203889    0.716272
# ...

# %%
ndg = nd[nd.units == 'g']
table = pivot_table(ndg, 'value', rows=['nutgroup', 'nutrient'], cols=['fgroup'],
                    aggfunc=np.max)
table[['Breakfast Cereals', 'Fast Foods', 'Sweets', 'Snacks']]
# Out:
# fgroup                                          Breakfast Cereals  Fast Foods  \
# nutgroup    nutrient
# Amino Acids Alanine                                         1.858       1.647
#             Arginine                                        2.348       1.635
#             Aspartic acid                                   2.604       1.964
#             Cystine                                         0.576       0.473
#             Glutamic acid                                   5.026       6.762
#             Glycine                                         1.791       2.431
#             Histidine                                       0.810       0.689
#             Hydroxyproline                                  0.000       0.803
#             Isoleucine                                      1.066       1.066
#             Leucine                                         2.410       1.763
#             Lysine                                          1.847       1.693
# ...

# %%
portions = []
for rec in db:
    portion = DataFrame(rec['portions'])
    portion['id'] = rec['id']
    portions.append(portion)
portions = concat(portions, ignore_index=True)

# %%
portions
# Out:
#        amount   grams     id                                 unit
# 0           1   28.35   1008                                   oz
# 1           1  132.00   1009                           cup, diced
# 2           2  244.00   1009                          cup, melted
# 3           3  113.00   1009                        cup, shredded
# 4           4   28.35   1009                                   oz
# 5           5   17.00   1009                           cubic inch
# 6           6   28.00   1009                         slice (1 oz)
# 7           1   28.35   1018                                   oz
# 8           2  198.00   1018                       package (7 oz)
# 9           1  150.00   1019                        cup, crumbled
# 10          2   28.35   1019                                   oz
# 11          3   17.00   1019                           cubic inch
# 12          4   38.00   1019                      wedge (1.33 oz)
# ...

# %%
portions[:50]
# Out:
#     amount   grams    id                              unit
# 0        1   28.35  1008                                oz
# 1        1  132.00  1009                        cup, diced
# 2        2  244.00  1009                       cup, melted
# 3        3  113.00  1009                     cup, shredded
# 4        4   28.35  1009                                oz
# 5        5   17.00  1009                        cubic inch
# 6        6   28.00  1009                      slice (1 oz)
# 7        1   28.35  1018                                oz
# 8        2  198.00  1018                    package (7 oz)
# 9        1  150.00  1019                     cup, crumbled
# 10       2   28.35  1019                                oz
# 11       3   17.00  1019                        cubic inch
# 12       4   38.00  1019                   wedge (1.33 oz)
# 13       1   28.35  1028                                oz
# 14       1  132.00  1029                        cup, diced
# ...

# %%
db[0]
# Out:
# {'description': 'Cheese, caraway',
#  'tags': [],
#  'portions': [{'amount': 1, 'grams': 28.35, 'unit': 'oz'}],
#  'group': 'Dairy and Egg Products',
#  'nutrients': [{'description': 'Protein',
#    'units': 'g',
#    'value': 25.18,
#    'group': 'Composition'},
#   {'description': 'Total lipid (fat)',
#    'units': 'g',
#    'value': 29.2,
#    'group': 'Composition'},
#   {'description': 'Carbohydrate, by difference',
#    'units': 'g',
#    'value': 3.06,
#    'group': 'Composition'},
#   {'description': 'Ash', 'units': 'g', 'value': 3.28, 'group': 'Other'},
#   {'description': 'Energy',
#    'units': 'kcal',
#    'value': 376.0,
#    'group': 'Energy'},
#   {'description': 'Water',
#    'units': 'g',
#    'value': 39.28,
#    'group': 'Composition'},
#   {'description': 'Energy', 'units': 'kJ', 'value': 1573.0, 'group': 'Energy'},
#   {'description': 'Fiber, total dietary',
#    'units': 'g',
#    'value': 0.0,
#    'group': 'Composition'},
#   {'description': 'Calcium, Ca',
# ...

# %%
for rec in db:
    if len(rec['portions']) > 1:
        break
nuts = DataFrame(rec['nutrients']).sort_index(by='description').drop_duplicates()
nuts
nuts[nuts.units == 'g']['value'].sum()
# Out:
# 159.62799999999999

# %%
tots = []
for rec in db:
    #if len(rec['portions']) > 1:
    #    break
    nuts = DataFrame(rec['nutrients']).sort_index(by='description').drop_duplicates()
    nuts
    tots.append(nuts[nuts.units == 'g']['value'].sum())
print(np.mean(tots))
# Out:
# 128.729191983

# %%
nd.nutrient.value_counts().index
# Out:
# Index(['Total lipid (fat)', 'Protein', 'Energy', 'Carbohydrate, by difference', 'Water', 'Ash', 'Sodium, Na', 'Iron, Fe', 'Calcium, Ca', 'Potassium, K', 'Fatty acids, total saturated', 'Cholesterol', 'Vitamin A, IU', 'Vitamin C, total ascorbic acid', 'Phosphorus, P', 'Riboflavin', 'Thiamin', 'Niacin', 'Zinc, Zn', 'Magnesium, Mg', 'Fatty acids, total polyunsaturated', 'Fatty acids, total monounsaturated', 'Copper, Cu', 'Vitamin B-6', 'Fiber, total dietary', 'Vitamin B-12', 'Folate, total', 'Vitamin A, RAE', 'Folate, food', 'Selenium, Se', 'Folic acid', 'Pantothenic acid', 'Folate, DFE', 'Retinol', 'Manganese, Mn', 'Sugars, total', 'Lysine', 'Methionine', 'Isoleucine', 'Leucine', 'Valine', 'Threonine', 'Phenylalanine', 'Histidine', 'Arginine', 'Vitamin E (alpha-tocopherol)', 'Tyrosine', 'Tryptophan', 'Glutamic acid', 'Aspartic acid', 'Serine', 'Cystine', 'Glycine', 'Alanine', 'Proline', 'Alcohol, ethyl', 'Carotene, beta', 'Vitamin D', 'Vitamin D (D2 + D3)', 'Carotene, alpha', 'Cryptoxa
# ...

# %%
kinds = ['Protein', 'Total lipid (fat)', 'Carbohydrate, by difference',
         'Fiber, total dietary']
for_plot = nd[nd.nutrient.isin(kinds)]

# %%
import pandas.tools.plotting as foo
#pd.reload(foo)

from pandas.tools.plotting import grouped_hist
for_plot['logv'] = np.log(for_plot['value'])
grouped_hist(for_plot, 'logv', by='nutrient')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x12474ff98>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x126619828>]], dtype=object)

# %%
grouped_hist(for_plot, 'value', by='nutrient')
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x124747da0>,
# ...
#         <matplotlib.axes.AxesSubplot object at 0x1268e02e8>]], dtype=object)

# %% [markdown]
# Um, need to deal with units??
# =============================

# %%
uniques = nd[['nutrient', 'units']].drop_duplicates().sort_index(by='nutrient')
uniques[:20]
# uniques.nutrient.value_counts()
# Out:
#                            nutrient units
# 289814             Adjusted Protein     g
# 48                          Alanine     g
# 62                   Alcohol, ethyl     g
# 46                         Arginine     g
# 3                               Ash     g
# 49                    Aspartic acid     g
# 1070                Beta-sitosterol    mg
# 107                         Betaine    mg
# 64                         Caffeine    mg
# 8                       Calcium, Ca    mg
# 1069                    Campesterol    mg
# 2       Carbohydrate, by difference     g
# 84                  Carotene, alpha   mcg
# 83                   Carotene, beta   mcg
# 32                      Cholesterol    mg
# 102                  Choline, total    mg
# 15                       Copper, Cu    mg
# 89              Cryptoxanthin, beta   mcg
# 42                          Cystine     g
# 114            Dihydrophylloquinone   mcg

# %%
nd.irow(nd.value.argmin())
# Out:
# nutrient                    Copper, Cu
# nutgroup                      Elements
# units                               mg
# value                            0.024
# id                                1008
# food                   Cheese, caraway
# fgroup          Dairy and Egg Products
# manufacturer
# Name: 15, dtype: object

# %%
by_nutrient = nd.groupby(['nutgroup', 'nutrient'])


# by_nutrient = nd.groupby([['nutrient'])
get_maximum = lambda x: x.xs(x.value.idxmax())
get_minimum = lambda x: x.xs(x.value.idxmin())

max_foods = by_nutrient.apply(get_maximum)[['value', 'food']]

# make the food a little smaller
max_foods['food'] = [x[:50] for x in max_foods['food']]
max_foods
# Out:
#                                                  value  \
# nutgroup    nutrient
# Amino Acids Alanine                              8.009
#             Arginine                             7.436
#             Aspartic acid                       10.203
#             Cystine                              1.307
#             Glutamic acid                       17.452
#             Glycine                             19.049
#             Histidine                            2.999
#             Hydroxyproline                       0.803
#             Isoleucine                           4.300
#             Leucine                              7.200
#             Lysine                               6.690
#             Methionine                           1.859
#             Phenylalanine                        4.600
#             Proline                             12.295
#             Serine                               4.600
#             Threonine                            3.300
# ...

# %%
mcdonalds.value.idxmax()
# Out:
# 239836

# %%
mcdonalds.xs(mcdonalds.value.idxmax())
# Out:
# nutrient                                   Vitamin A, IU
# nutgroup                                        Vitamins
# units                                                 IU
# value                                               3024
# id                                                 21372
# food            McDONALD'S, Caesar Salad without chicken
# fgroup                                        Fast Foods
# manufacturer                      McDonald's Corporation
# Name: 239836, dtype: object

# %%
mcdonalds.index
# Out:
# Int64Index([232978, 232990, 232977, 233007, 232997, 232979, 233010, 233011, 233009, 233008, 232989, 233005, 232982, 232988, 232981, 232991, 232983, 232992, 232984, 232998, 233004, 232993, 232994, 232975, 233003, 232995, 232980, 232987, 233002, 232976, 232999, 233000, 233006, 233001, 232985, 232996, 233162, 233168, 233161, 233184, 233175, 233163, 233187, 233188, 233186, 233185, 233167, 233182, 233169, 233170, 233176, 233181, 233171, 233172, 233159, 233180, 233173, 233166, 233179, 233160, 233177, 233183, 233178, 233164, 233174, 233192, 233204, 233191, 233220, 233211, 233193, 233223, 233224, 233222, 233221, 233203, 233218, 233196, 233202, 233195, 233205, 233197, 233206, 233198, 233212, 233217, 233207, 233208, 233189, 233216, 233209, 233194, 233201, 233215, 233190, 233213, 233219, 233214, 233199, 233210, ...], dtype='int64')

# %%
mcdonalds.value.argmax()
# Out:
# 239836

# %%
mcdonalds.ix[mcdonalds.value.argmax()]
# Out:
# nutrient                                   Vitamin A, IU
# nutgroup                                        Vitamins
# units                                                 IU
# value                                               3024
# id                                                 21372
# food            McDONALD'S, Caesar Salad without chicken
# fgroup                                        Fast Foods
# manufacturer                      McDonald's Corporation
# Name: 239836, dtype: object

# %%
mcdonalds.loc[239836]
# Out:
# nutrient                                   Vitamin A, IU
# nutgroup                                        Vitamins
# units                                                 IU
# value                                               3024
# id                                                 21372
# food            McDONALD'S, Caesar Salad without chicken
# fgroup                                        Fast Foods
# manufacturer                      McDonald's Corporation
# Name: 239836, dtype: object

# %%
mcdonalds = nd[['mcdonald' in x.lower() for x in nd.food]]

by_nutrient = mcdonalds.groupby(['nutgroup', 'nutrient'])
#by_nutrient = nd.groupby(['nutrient'])
get_maximum = lambda x: x.xs(x.value.argmax())
get_minimum = lambda x: x.xs(x.value.argmin())

#get_maximum = lambda x: x.ix[x.value.argmax()]
#get_minimum = lambda x: x.ix[x.value.argmin()]

max_foods = by_nutrient.apply(get_maximum)[['value', 'food']]

# make the food a little smaller
max_foods['food'] = [x[:50] for x in max_foods['food']]
max_foods
# Out:
#                                                    value  \
# nutgroup    nutrient
# Composition Carbohydrate, by difference           86.440
#             Fiber, total dietary                   5.000
#             Protein                               28.040
#             Sugars, total                         74.320
#             Total lipid (fat)                     52.910
#             Water                                 93.930
# Elements    Calcium, Ca                          292.000
#             Copper, Cu                             0.408
#             Iron, Fe                               3.890
#             Magnesium, Mg                        193.000
#             Manganese, Mn                          2.000
#             Phosphorus, P                        442.000
#             Potassium, K                         634.000
#             Selenium, Se                           0.400
#             Sodium, Na                          2140.000
# ...

# %%
wendys = nd[['wendy' in x.lower() for x in nd.food]]

by_nutrient = wendys.groupby(['nutgroup', 'nutrient'])
# by_nutrient = nd.groupby([['nutrient'])
get_maximum = lambda x: x.xs(x.value.argmax())
get_minimum = lambda x: x.xs(x.value.argmin())

max_foods = by_nutrient.apply(get_maximum)[['value', 'food']]

# make the food a little smaller
max_foods['food'] = [x[:50] for x in max_foods['food']]
max_foods
# Out:
#                                                   value  \
# nutgroup    nutrient
# Amino Acids Alanine                               0.860
#             Arginine                              0.840
#             Aspartic acid                         1.245
#             Cystine                               0.190
#             Glutamic acid                         2.480
#             Glycine                               0.930
#             Histidine                             0.470
#             Isoleucine                            0.635
#             Leucine                               1.103
#             Lysine                                1.090
#             Methionine                            0.357
#             Phenylalanine                         0.580
#             Proline                               0.900
#             Serine                                0.600
#             Threonine                             0.602
# ...

# %%
wendys
# Out:
#                                   nutrient     nutgroup units    value     id  \
# 153413                                 Ash        Other     g    0.040  14601
# 153416                            Caffeine        Other    mg    8.000  14601
# 153419                         Calcium, Ca     Elements    mg    2.000  14601
# 153412         Carbohydrate, by difference  Composition     g    0.000  14601
# 153426                          Copper, Cu     Elements    mg    0.008  14601
# 153414                              Energy       Energy  kcal    1.000  14601
# 153435  Fatty acids, total monounsaturated        Other     g    0.000  14601
# 153436  Fatty acids, total polyunsaturated        Other     g    0.000  14601
# 153434        Fatty acids, total saturated        Other     g    0.000  14601
# 153420                            Iron, Fe     Elements    mg    0.000  14601
# 153421                       Magnesium, Mg     Elements    mg    1.000  14601
# ...
