# %% [markdown]
# # Home Work 01

# %% [markdown]
# 使用quick sort, bubble sort, selection Sort
#
# 比較個個sort的速度（使用亂產生100,200 每次增加100 直到 10000 的list）
#
# 每個 sort 需要執行過100次在取平均值
#
# 並且畫出圖形
#
# 例如：

# %% [markdown]
# 為了解決 ipython notebook 中文亂碼問題，必須改變字體
#
#     font = {'fontname':'LiHei Pro', 'fontsize':14}
#     plt.rcParams['font.sans-serif'] = ['LiHei Pro']
#
# 其中`fontname` 為字體名稱
#
# 透過最下面的 code 可以找出有哪些字體可以正常顯示中文

# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

font = {'fontname':'LiHei Pro', 'fontsize':14}

import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['LiHei Pro']

fig, ax = plt.subplots()

ax.plot([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
       [0.0021144300000003114,
          0.008709889999999306,
          0.02032959999999939,
          0.03538064999999932,
          0.05443392000000074,
          0.0835494100000001,
          0.11036593000000025,
          0.14348852999999948,
          0.1822293399999998,
          0.22617954000000054],
       label="bubble")

ax.plot([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
        [0.00035946999999971754,
          0.0011776899999993873,
          0.0024865800000003447,
          0.003930219999999878,
          0.005885099999998573,
          0.008849759999999379,
          0.011439059999999869,
          0.014930749999998908,
          0.01843473999999915,
          0.023004859999998642],
        label="selection")

ax.plot([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
        [0.0003639899999998875,
          0.0007965600000001416,
          0.0012917400000004165,
          0.0016358500000001185,
          0.0020120999999994637,
          0.0025952099999990708,
          0.0029270900000001633,
          0.0033919000000001633,
          0.0037991399999994257,
          0.004299870000001818],
        label="quick")
ax.legend(loc=2); # upper left corner
ax.set_xlabel("次數",font)
ax.set_ylabel("時間(秒)", font)
ax.set_title('標題')

#ax.axis([0, 500, 0, 20])
plt.show()

# %%
# %pylab inline 
from matplotlib.font_manager import fontManager 
import matplotlib.pyplot as plt 
import os 
import os.path 

fig = plt.figure(figsize=(18,50)) 
ax = fig.add_subplot(111) 
plt.subplots_adjust(0, 0, 1, 1, 0, 0) 
plt.xticks([]) 
plt.yticks([]) 
x, y = 0.05, 0.18 
fonts = [font.name for font in fontManager.ttflist if 
    os.path.exists(font.fname)] 
font = set(fonts) 
dy = (1.0-y)/(len(fonts)/4 + (len(fonts)%4!=0)) 
for font in fonts: 
    t = ax.text(x, y, "中文字體", {'fontname':font, 'fontsize':14}, transform=ax.transAxes) 
    ax.text(x, y-dy/2, font, transform=ax.transAxes) 
    x += 0.25 
    if x >= 1.0: 
        y += dy 
        x = 0.05 
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
